# %%
import os

base_dir = os.path.join(os.path.dirname("notebook.ipynb"), "..")

# %%
dir = os.path.dirname("a:\\Python Project\\DocManager\\app\\notebook.ipynb")

# %%
os.abspath(os.path.join(dir,".."))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.abspath(os.path.join(dir,".."))
#
# AttributeError: module 'os' has no attribute 'abspath'

# %%
a = os.path.join(dir,"..")
a
# Out:
# 'a:\\Python Project\\DocManager\\app\\..'

# %%
os.path.abspath(a)
# Out:
# 'a:\\Python Project\\DocManager'

# %%
os.getcwd()
# Out:
# 'a:\\Python Project\\DocManager\\app'

# %%
DB_PATH = os.path.abspath(os.path.join("Data", "pdf.db"))

# %%
DB_PATH
# Out:
# 'a:\\Python Project\\DocManager\\app\\Data\\pdf.db'

# %%
DB_PATH = 'a:\\Python Project\\DocManager\\Data\\pdf.db'
