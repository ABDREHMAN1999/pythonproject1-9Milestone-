# %%
print("Hello")
import os 
import sqlite3
# Out:
# Hello

# %%
os.getcwd()
# Out:
# 'a:\\Python Project\\DocManager\\app'

# %%
path = 'a:\\Python Project\\DocManager\\Data\\pdf.db'

# %%
connection = sqlite3.connect(path)
cursor = connection.cursor()

# %%
cursor.execute("""
               SELECT * FROM docuemts
               """)

# %%
cursor.fetchall()
# Out:
# [(None,
#   'Rohith_Sai Kotra_Resume.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\03042026235254_Rohith_Sai Kotra_Resume.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\03042026235254_Rohith_Sai Kotra_Resume.jpeg',
#   'kncsln',
#   'njsjdcjk',
#   '03042026',
#   '2026-04-20',
#   2),
#  (None,
#   'Rohith_Sai Kotra_Resume.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\04042026004817_Rohith_Sai Kotra_Resume.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\04042026004817_Rohith_Sai Kotra_Resume.jpeg',
#   '',
#   '',
#   '04042026',
#   None,
#   2),
#  (None,
#   'Rohith_Sai Kotra_Resume.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\04042026103853_Rohith_Sai Kotra_Resume.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\04042026103853_Rohith_Sai Kotra_Resume.jpeg',
#   'Rohit , Resume ',
#   'this is Rohits resume ',
#   '04042026',
#   '2026-04-04',
#   2)]

# %%
cursor.execute("""
               DELETE FROM docuemts WHERE name IS NOT NULL
               
               """)

# %%
cursor.fetchall()
# Out:
# []
