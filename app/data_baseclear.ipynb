# %%
print("Hello")
import os 
import sqlite3
# Out:
# Hello

# %%
os.getcwd()
# Out:
# 'a:\\Python Project\\DocManager\\app'

# %%
path = 'a:\\Python Project\\DocManager\\Data\\pdf.db'

# %%
connection = sqlite3.connect(path)
cursor = connection.cursor()

# %%
cursor.execute("""
               SELECT * FROM docuemts
               """)

# %%
cursor.fetchall()
# Out:
# [(None,
#   'Mohammed_Tameem.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\05042026095352_Mohammed_Tameem.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\05042026095352_Mohammed_Tameem.jpeg',
#   "Resume Tameem's",
#   'tamim bhai ka resume ',
#   '05042026',
#   '2026-04-05',
#   1),
#  (None,
#   'Rohith_Sai Kotra_Resume.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\05042026095434_Rohith_Sai Kotra_Resume.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\05042026095434_Rohith_Sai Kotra_Resume.jpeg',
#   'Rohits resume ',
#   'rohit bhai ka resume ',
#   '05042026',
#   '2026-04-05',
#   2),
#  (None,
#   'Abdulrehman_resume_SAP_SECURITY_GRC_IAG.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\05042026095512_Abdulrehman_resume_SAP_SECURITY_GRC_IAG.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\05042026095512_Abdulrehman_resume_SAP_SECURITY_GRC_IAG.jpeg',
#   'My resume',
#   'Abduls own resume ',
# ...

# %%
cursor.execute("""
               DELETE FROM docuemts WHERE name IS NOT NULL
               
               """)

# %%
connection.commit()
connection.close()
