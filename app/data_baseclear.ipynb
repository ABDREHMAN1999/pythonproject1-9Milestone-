# %%
print("Hello")
import os 
import sqlite3
# Out:
# Hello

# %%
os.getcwd()
# Out:
# 'a:\\Python Project\\DocManager\\app'

# %%
path = 'a:\\Python Project\\DocManager\\Data\\pdf.db'

# %%
connection = sqlite3.connect(path)
cursor = connection.cursor()

# %%
cursor.execute("""
               SELECT * FROM docuemts
               """)

# %%
cursor.fetchall()
# Out:
# [(None,
#   'Rohith_Sai Kotra_Resume.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\05042026012337_Rohith_Sai Kotra_Resume.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\05042026012337_Rohith_Sai Kotra_Resume.jpeg',
#   '',
#   '',
#   '05042026',
#   None,
#   2)]

# %%
cursor.execute("""
               DELETE FROM docuemts WHERE name IS NOT NULL
               
               """)

# %%
connection.commit()
connection.close()
