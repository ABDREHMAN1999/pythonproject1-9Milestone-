# %%
print("Hello")
import os 
import sqlite3
# Out:
# Hello

# %%
os.getcwd()
# Out:
# 'a:\\Python Project\\DocManager\\app'

# %%
path = 'a:\\Python Project\\DocManager\\Data\\pdf.db'

# %%
connection = sqlite3.connect(path)
cursor = connection.cursor()

# %%
cursor.execute("""
               SELECT * FROM docuemts
               """)

# %%
cursor.fetchall()
# Out:
# [(1,
#   'Abdulrehman_resume_SAP_SECURITY_GRC_IAG.pdf',
#   "A:\\Python Project\\DocManager\\storage\\pdf's\\06042026184400_Abdulrehman_resume_SAP_SECURITY_GRC_IAG.pdf",
#   'A:\\Python Project\\DocManager\\storage\\thumnails\\06042026184400_Abdulrehman_resume_SAP_SECURITY_GRC_IAG.jpeg',
#   'My resume SAP Security',
#   'Abdulrehman Shaikh SAP Security resume',
#   '06042026',
#   '2026-04-06',
#   2)]

# %%
cursor.execute("""
               DELETE FROM docuemts WHERE name IS NOT NULL
               
               """)

# %%
connection.commit()
connection.close()
